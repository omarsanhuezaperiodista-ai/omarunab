# %%
import pandas as pd

df = pd.read_csv("universal_top_spotify_songs.csv")

df.shape
df.head()
df.info()
df.isnull().sum()
df.duplicated().sum()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2110316 entries, 0 to 2110315
# Data columns (total 25 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   spotify_id          str
#  1   name                str
#  2   artists             str
#  3   daily_rank          int64
#  4   daily_movement      int64
#  5   weekly_movement     int64
#  6   country             str
#  7   snapshot_date       str
#  8   popularity          int64
#  9   is_explicit         bool
#  10  duration_ms         int64
#  11  album_name          str
#  12  album_release_date  str
#  13  danceability        float64
#  14  energy              float64
#  15  key                 int64
#  16  loudness            float64
#  17  mode                int64
#  18  speechiness         float64
#  19  acousticness        float64
#  20  instrumentalness    float64
#  21  liveness            float64
#  22  valence             float64
#  23  tempo               float64
#  24  time_signature      int64
# dtypes: bool(1), float64(9), int64(8), str(7)
# memory usage: 388.4 MB
#          daily_rank  daily_movement  weekly_movement    popularity  \
# count  2.110316e+06    2.110316e+06     2.110316e+06  2.110316e+06
# mean   2.549302e+01    9.230660e-01     2.932522e+00  7.590713e+01
# std    1.442900e+01    7.015535e+00     1.233129e+01  1.576302e+01
# min    1.000000e+00   -4.900000e+01    -4.900000e+01  0.000000e+00
# 25%    1.300000e+01   -1.000000e+00    -3.000000e+00  6.500000e+01
# 50%    2.500000e+01    0.000000e+00     0.000000e+00  7.900000e+01
# 75%    3.800000e+01    2.000000e+00     5.000000e+00  8.800000e+01
# max    5.000000e+01    4.900000e+01     4.900000e+01  1.000000e+02
#
#         duration_ms  danceability        energy           key      loudness  \
# count  2.110316e+06  2.110316e+06  2.110316e+06  2.110316e+06  2.110316e+06
# mean   1.943095e+05  6.759191e-01  6.488031e-01  5.526496e+00 -6.772439e+00
# std    4.986054e+04  1.440469e-01  1.689142e-01  3.594979e+00  3.874849e+00
# min    0.000000e+00  0.000000e+00  2.010000e-05  0.000000e+00 -5.434100e+01
# 25%    1.626370e+05  5.800000e-01  5.520000e-01  2.000000e+00 -7.830000e+00
# 50%    1.861910e+05  7.000000e-01  6.680000e-01  6.000000e+00 -6.064000e+00
# 75%    2.187010e+05  7.800000e-01  7.670000e-01  9.000000e+00 -4.723000e+00
# max    1.296000e+06  9.880000e-01  9.980000e-01  1.100000e+01  3.233000e+00
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  2.110316e+06  2.110316e+06  2.110316e+06      2.110316e+06
# mean   5.364571e-01  9.550408e-02  2.748491e-01      2.316185e-02
# std    4.986692e-01  9.138830e-02  2.509297e-01      1.137297e-01
# min    0.000000e+00  0.000000e+00  3.450000e-06      0.000000e+00
# 25%    0.000000e+00  3.840000e-02  6.670000e-02      0.000000e+00
# 50%    1.000000e+00  5.810000e-02  1.910000e-01      1.340000e-06
# 75%    1.000000e+00  1.120000e-01  4.370000e-01      1.010000e-04
# max    1.000000e+00  9.570000e-01  9.960000e-01      9.950000e-01
#
#            liveness       valence         tempo  time_signature
# count  2.110316e+06  2.110316e+06  2.110316e+06    2.110316e+06
# mean   1.705588e-01  5.462535e-01  1.221008e+02    3.900368e+00
# std    1.247528e-01  2.311527e-01  2.781938e+01    4.044448e-01
# min    1.390000e-02  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    9.610000e-02  3.700000e-01  1.000190e+02    4.000000e+00
# 50%    1.220000e-01  5.480000e-01  1.199650e+02    4.000000e+00
# 75%    2.040000e-01  7.330000e-01  1.400210e+02    4.000000e+00
# max    9.830000e-01  9.920000e-01  2.360890e+02    5.000000e+00

# %%
df["country"].nunique()
df["country"].unique()
df["snapshot_date"].min(), df["snapshot_date"].max()
# Out:
# ('2023-10-18', '2025-06-11')

# %%
print("Cantidad de países:", df["country"].nunique())
print("Países:", df["country"].unique())
print("Rango de fechas:", df["snapshot_date"].min(), "a", df["snapshot_date"].max())
# Out:
# Cantidad de países: 72
# Países: <StringArray>
# [ nan, 'ZA', 'VN', 'VE', 'UY', 'US', 'UA', 'TW', 'TR', 'TH', 'SV', 'SK', 'SG',
#  'SE', 'SA', 'RO', 'PY', 'PT', 'PL', 'PK', 'PH', 'PE', 'PA', 'NZ', 'NO', 'NL',
#  'NI', 'NG', 'MY', 'MX', 'MA', 'LV', 'LU', 'LT', 'KZ', 'KR', 'JP', 'IT', 'IS',
#  'IN', 'IL', 'IE', 'ID', 'HU', 'HN', 'HK', 'GT', 'GR', 'FR', 'FI', 'ES', 'EG',
#  'EE', 'EC', 'DO', 'DK', 'DE', 'CZ', 'CR', 'CO', 'CL', 'CH', 'CA', 'BY', 'BR',
#  'BO', 'BG', 'BE', 'AU', 'AT', 'AR', 'AE', 'GB']
# Length: 73, dtype: str
# Rango de fechas: 2023-10-18 a 2025-06-11

# %%
df["country"].isna().sum()
# Out:
# np.int64(28908)

# %%
print("Registros y columnas:", df.shape)
print("Cantidad de países:", df["country"].nunique())
print("Valores únicos en country:", len(df["country"].unique()))
print("Rango de fechas:", df["snapshot_date"].min(), "a", df["snapshot_date"].max())

missing_country = df["country"].isna().sum()
total = len(df)
print("Registros sin país:", missing_country)
print("Porcentaje sin país:", round(missing_country / total * 100, 2), "%")
# Out:
# Registros y columnas: (2110316, 25)
# Cantidad de países: 72
# Valores únicos en country: 73
# Rango de fechas: 2023-10-18 a 2025-06-11
# Registros sin país: 28908
# Porcentaje sin país: 1.37 %

# %%
# Intento inicial descartado: el dataset no usa "Chile", sino el código "CL" 
# chile = df[df["country"] == "Chile"]

# chile.shape
# chile["snapshot_date"].min(), chile["snapshot_date"].max()
# chile["name"].nunique()
# chile["artists"].nunique()

# %%
chile = df[df["country"] == "CL"]

print("Registros de Chile:", chile.shape)
print("Rango de fechas Chile:", chile["snapshot_date"].min(), "a", chile["snapshot_date"].max())
print("Canciones únicas en Chile:", chile["name"].nunique())
print("Artistas únicos en Chile:", chile["artists"].nunique())
# Out:
# Registros de Chile: (29105, 25)
# Rango de fechas Chile: 2023-10-18 a 2025-06-11
# Canciones únicas en Chile: 540
# Artistas únicos en Chile: 408

# %%
missing_country = df["country"].isna().sum()
total = len(df)
missing_percent = missing_country / total * 100

print("Registros sin país:", missing_country)
print("Porcentaje sin país:", round(missing_percent, 2), "%")
# Out:
# Registros sin país: 28908
# Porcentaje sin país: 1.37 %

# %%
global_check = df[df["country"].isna()]

print("Registros con country nulo:", global_check.shape)
print("Rango de fechas:", global_check["snapshot_date"].min(), "a", global_check["snapshot_date"].max())
print("Canciones únicas:", global_check["name"].nunique())
print("Artistas únicos:", global_check["artists"].nunique())

global_check[["name", "artists", "daily_rank", "snapshot_date", "country"]].head(10)
# Out:
# Registros con country nulo: (28908, 25)
# Rango de fechas: 2023-10-18 a 2025-06-11
# Canciones únicas: 781
# Artistas únicos: 434
#                     name                           artists  daily_rank  \
# 0               Ordinary                       Alex Warren           1
# 1               Manchild                 Sabrina Carpenter           2
# 2        back to friends                             sombr           3
# 3       Die With A Smile             Lady Gaga, Bruno Mars           4
# 4     BIRDS OF A FEATHER                     Billie Eilish           5
# 5  Don’t Say You Love Me                               Jin           6
# 6  La Plena - W Sound 05  W Sound, Beéle, Ovy On The Drums           7
# 7              undressed                             sombr           8
# 8                   APT.                  ROSÉ, Bruno Mars           9
# 9            Love Me Not                       Ravyn Lenae          10
#
#   snapshot_date country
# 0    2025-06-11     NaN
# 1    2025-06-11     NaN
# 2    2025-06-11     NaN
# 3    2025-06-11     NaN
# 4    2025-06-11     NaN
# 5    2025-06-11     NaN
# 6    2025-06-11     NaN
# 7    2025-06-11     NaN
# 8    2025-06-11     NaN
# 9    2025-06-11     NaN

# %%
global_check.groupby("snapshot_date")["daily_rank"].count().describe()
# Out:
# count    578.000000
# mean      50.013841
# std        0.262930
# min       47.000000
# 25%       50.000000
# 50%       50.000000
# 75%       50.000000
# max       54.000000
# Name: daily_rank, dtype: float64

# %%
# Análisis de consistencia de rangos esperados

print("daily_rank fuera de 1 a 50:",
      ((df["daily_rank"] < 1) | (df["daily_rank"] > 50)).sum())

print("daily_movement fuera de -49 a 49:",
      ((df["daily_movement"] < -49) | (df["daily_movement"] > 49)).sum())

print("weekly_movement fuera de -49 a 49:",
      ((df["weekly_movement"] < -49) | (df["weekly_movement"] > 49)).sum())

print("popularity fuera de 0 a 100:",
      ((df["popularity"] < 0) | (df["popularity"] > 100)).sum())

audio_cols = [
    "danceability", "energy", "speechiness", "acousticness",
    "instrumentalness", "liveness", "valence"
]

for col in audio_cols:
    fuera_rango = ((df[col] < 0) | (df[col] > 1)).sum()
    print(f"{col} fuera de 0 a 1:", fuera_rango)

print("key fuera de 0 a 11:",
      ((df["key"] < 0) | (df["key"] > 11)).sum())

print("mode fuera de 0 a 1:",
      (~df["mode"].isin([0, 1])).sum())

print("time_signature fuera de 1 a 5:",
      ((df["time_signature"] < 1) | (df["time_signature"] > 5)).sum())

print("duration_ms igual a 0:",
      (df["duration_ms"] == 0).sum())

print("tempo igual a 0:",
      (df["tempo"] == 0).sum())
# Out:
# daily_rank fuera de 1 a 50: 0
# daily_movement fuera de -49 a 49: 0
# weekly_movement fuera de -49 a 49: 0
# popularity fuera de 0 a 100: 0
# danceability fuera de 0 a 1: 0
# energy fuera de 0 a 1: 0
# speechiness fuera de 0 a 1: 0
# acousticness fuera de 0 a 1: 0
# instrumentalness fuera de 0 a 1: 0
# liveness fuera de 0 a 1: 0
# valence fuera de 0 a 1: 0
# key fuera de 0 a 11: 0
# mode fuera de 0 a 1: 0
# time_signature fuera de 1 a 5: 1
# duration_ms igual a 0: 29
# tempo igual a 0: 1

# %%
# Revisión de consistencia en fechas

fechas_convertidas = pd.to_datetime(df["snapshot_date"], errors="coerce")
fechas_invalidas = fechas_convertidas.isna().sum()

print("Fechas inválidas en snapshot_date:", fechas_invalidas)
print("Fecha mínima:", fechas_convertidas.min())
print("Fecha máxima:", fechas_convertidas.max())
# Out:
# Fechas inválidas en snapshot_date: 0
# Fecha mínima: 2023-10-18 00:00:00
# Fecha máxima: 2025-06-11 00:00:00

# %%
# Variables numéricas donde revisaremos posibles valores atípicos
outlier_cols = [
    "duration_ms", "tempo", "loudness", "popularity",
    "daily_movement", "weekly_movement"
]

# Resumen estadístico ampliado
df[outlier_cols].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
#         duration_ms         tempo      loudness    popularity  daily_movement  \
# count  2.110316e+06  2.110316e+06  2.110316e+06  2.110316e+06    2.110316e+06
# mean   1.943095e+05  1.221008e+02 -6.772439e+00  7.590713e+01    9.230660e-01
# std    4.986054e+04  2.781938e+01  3.874849e+00  1.576302e+01    7.015535e+00
# min    0.000000e+00  0.000000e+00 -5.434100e+01  0.000000e+00   -4.900000e+01
# 1%     1.058360e+05  7.199400e+01 -2.740500e+01  3.100000e+01   -1.400000e+01
# 5%     1.308800e+05  8.197100e+01 -1.186000e+01  4.900000e+01   -7.000000e+00
# 25%    1.626370e+05  1.000190e+02 -7.830000e+00  6.500000e+01   -1.000000e+00
# 50%    1.861910e+05  1.199650e+02 -6.064000e+00  7.900000e+01    0.000000e+00
# 75%    2.187010e+05  1.400210e+02 -4.723000e+00  8.800000e+01    2.000000e+00
# 95%    2.763860e+05  1.737200e+02 -3.086000e+00  9.600000e+01    1.000000e+01
# 99%    3.547840e+05  1.920550e+02 -1.978000e+00  9.900000e+01    3.600000e+01
# max    1.296000e+06  2.360890e+02  3.233000e+00  1.000000e+02    4.900000e+01
#
#        weekly_movement
# count     2.110316e+06
# mean      2.932522e+00
# std       1.233129e+01
# min      -4.900000e+01
# 1%       -2.000000e+01
# 5%       -1.200000e+01
# 25%      -3.000000e+00
# 50%       0.000000e+00
# 75%       5.000000e+00
# 95%       3.200000e+01
# 99%       4.600000e+01
# max       4.900000e+01

# %%
# Canciones con duración igual a cero
df[df["duration_ms"] == 0][["name", "artists", "duration_ms", "tempo", "country", "snapshot_date"]].head(20)
# Out:
#         name artists  duration_ms    tempo country snapshot_date
# 502366   NaN     NaN            0  126.006      MA    2025-01-15
# 790671   NaN     NaN            0  113.032      IS    2024-10-17
# 1420334  NaN     NaN            0  120.046      TR    2024-04-27
# 1420357  NaN     NaN            0  140.081      TR    2024-04-27
# 1567150  NaN     NaN            0   98.071      UY    2024-03-14
# 1570595  NaN     NaN            0   98.071      AR    2024-03-14
# 1773300  NaN     NaN            0  140.007      IS    2024-01-18
# 1928350  NaN     NaN            0  118.024      ZA    2023-12-06
# 2022978  NaN     NaN            0   90.019      VE    2023-11-10
# 2023310  NaN     NaN            0   90.019      SV    2023-11-10
# 2023847  NaN     NaN            0   90.019      PE    2023-11-10
# 2023924  NaN     NaN            0   90.019      PA    2023-11-10
# 2024138  NaN     NaN            0   90.019      NI    2023-11-10
# 2025006  NaN     NaN            0   90.019      HN    2023-11-10
# 2025110  NaN     NaN            0   90.019      GT    2023-11-10
# 2025343  NaN     NaN            0   90.019      ES    2023-11-10
# 2025498  NaN     NaN            0   90.019      EC    2023-11-10
# 2025752  NaN     NaN            0   90.019      CR    2023-11-10
# 2025823  NaN     NaN            0   90.019      CO    2023-11-10
# 2025840  NaN     NaN            0   90.019      CL    2023-11-10

# %%
# Canciones con mayor duración
df.sort_values("duration_ms", ascending=False)[
    ["name", "artists", "duration_ms", "tempo", "country", "snapshot_date"]
].head(20)
# Out:
#                                 name  \
# 12405              Secessioni, Pt. 3
# 114446  bissu dumm ¿ MEGALODON REMIX
# 136030  bissu dumm ¿ MEGALODON REMIX
# 154722  bissu dumm ¿ MEGALODON REMIX
# 168429  bissu dumm ¿ MEGALODON REMIX
# 169088  bissu dumm ¿ MEGALODON REMIX
# 118027  bissu dumm ¿ MEGALODON REMIX
# 121628  bissu dumm ¿ MEGALODON REMIX
# 165478  bissu dumm ¿ MEGALODON REMIX
# 168690  bissu dumm ¿ MEGALODON REMIX
# 164826  bissu dumm ¿ MEGALODON REMIX
# 163645  bissu dumm ¿ MEGALODON REMIX
# 125225  bissu dumm ¿ MEGALODON REMIX
# 165082  bissu dumm ¿ MEGALODON REMIX
# 128825  bissu dumm ¿ MEGALODON REMIX
# 161227  bissu dumm ¿ MEGALODON REMIX
# 161486  bissu dumm ¿ MEGALODON REMIX
# 151088  bissu dumm ¿ MEGALODON REMIX
# 158283  bissu dumm ¿ MEGALODON REMIX
# 157627  bissu dumm ¿ MEGALODON REMIX
#
#                                                   artists  duration_ms  \
# 12405                                           Neuf Voix      1296000
# 114446  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 136030  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 154722  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 168429  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 169088  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 118027  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 121628  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 165478  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 168690  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 164826  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 163645  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 125225  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 165082  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 128825  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 161227  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 161486  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 151088  Bonez MC, Nate57, Jugglerz, AchtVier, AK 33, A...      1114155
# 158283  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
# 157627  Bonez MC, Nate57, AchtVier, AK 33, AK AUSSERKO...      1114155
#
#           tempo country snapshot_date
# 12405   180.113      LU    2025-06-08
# 114446   94.964      DE    2025-05-11
# 136030   94.964      DE    2025-05-05
# 154722   94.908      AT    2025-04-30
# 168429   94.908      DE    2025-04-18
# 169088   94.908      AT    2025-04-18
# 118027   94.964      DE    2025-05-10
# 121628   94.964      DE    2025-05-09
# 165478   94.908      AT    2025-04-19
# 168690   94.908      CH    2025-04-18
# 164826   94.908      DE    2025-04-19
# 163645   94.908      LU    2025-04-19
# 125225   94.964      DE    2025-05-08
# 165082   94.908      CH    2025-04-19
# 128825   94.964      DE    2025-05-07
# 161227   94.908      DE    2025-04-20
# 161486   94.908      CH    2025-04-20
# 151088   94.964      AT    2025-05-01
# 158283   94.908      AT    2025-04-21
# 157627   94.908      DE    2025-04-21

# %%
df[df["tempo"] == 0][["name", "artists", "duration_ms", "tempo", "country", "snapshot_date"]]
# Out:
#                     name        artists  duration_ms  tempo country  \
# 1827453  El Fua (La Luz)  Alfonso Vélez       203160    0.0      NI
#
#         snapshot_date
# 1827453    2024-01-03

# %%
df_clean = df.copy()

# 1. Tratar country nulo como posible ranking global
df_clean["country_clean"] = df_clean["country"].fillna("Global_por_verificar")

# 2. Eliminar registros sin nombre, sin artista y con duración cero
condicion_incompleta = (
    df_clean["name"].isna() &
    df_clean["artists"].isna() &
    (df_clean["duration_ms"] == 0)
)

df_clean = df_clean[~condicion_incompleta]

# 3. Marcar tempo igual a cero como valor no interpretable
df_clean.loc[df_clean["tempo"] == 0, "tempo"] = pd.NA

# 4. Marcar time_signature fuera de rango como valor no interpretable
df_clean.loc[
    (df_clean["time_signature"] < 1) | (df_clean["time_signature"] > 5),
    "time_signature"
] = pd.NA

print("Registros originales:", df.shape[0])
print("Registros después de depuración:", df_clean.shape[0])
print("Registros eliminados:", df.shape[0] - df_clean.shape[0])
# Out:
# Registros originales: 2110316
# Registros después de depuración: 2110287
# Registros eliminados: 29

# %%
# Caracterización general del dataset limpio

print("Registros del dataset limpio:", df_clean.shape[0])
print("Columnas:", df_clean.shape[1])
print("Rango de fechas:", df_clean["snapshot_date"].min(), "a", df_clean["snapshot_date"].max())

print("Países/categorías en country_clean:", df_clean["country_clean"].nunique())
print("Canciones únicas:", df_clean["name"].nunique())
print("Valores únicos en artists:", df_clean["artists"].nunique())

print("Registros de Chile:", df_clean[df_clean["country_clean"] == "CL"].shape[0])
print("Registros posibles Global:", df_clean[df_clean["country_clean"] == "Global_por_verificar"].shape[0])
# Out:
# Registros del dataset limpio: 2110287
# Columnas: 26
# Rango de fechas: 2023-10-18 a 2025-06-11
# Países/categorías en country_clean: 73
# Canciones únicas: 21809
# Valores únicos en artists: 13726
# Registros de Chile: 29103
# Registros posibles Global: 28908

# %%
# Distribución de registros por país/categoría

conteo_paises = df_clean["country_clean"].value_counts().head(15)

print(conteo_paises)
# Out:
# country_clean
# DO    29176
# IT    29174
# NI    29169
# PL    29164
# HU    29163
# TH    29161
# KZ    29161
# HN    29161
# EG    29161
# CZ    29161
# SV    29160
# FI    29160
# PT    29159
# PK    29159
# FR    29159
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

conteo_paises = df_clean["country_clean"].value_counts().head(15)

plt.figure(figsize=(10, 6))
conteo_paises.sort_values().plot(kind="barh")
plt.title("Top 15 países/categorías con más registros")
plt.xlabel("Cantidad de registros")
plt.ylabel("País o categoría")
plt.tight_layout()
plt.show()

# %%
chile_clean = df_clean[df_clean["country_clean"] == "CL"]

top_artistas_chile = chile_clean["artists"].value_counts().head(15)

print(top_artistas_chile)
# Out:
# artists
# Cris Mj                                         1808
# Bad Bunny                                       1233
# KAROL G                                         1071
# Feid, ATL Jacob                                  489
# Tiago PZK, Ke Personajes                         399
# FloyyMenor, Lewis Somes                          394
# FloyyMenor, Cris Mj                              392
# Katteyes, Kidd Voodoo                            370
# Lucky Brown, Mateo on the Beatz                  357
# KAROL G, Peso Pluma                              354
# Myke Towers                                      340
# Jimin                                            321
# Plan B                                           318
# Lucky Brown, Big Cvyu                            311
# Jere Klein, Nickoog Clk, Lucky Brown, El BAI     308
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_artistas_chile = chile_clean["artists"].value_counts().head(15)

plt.figure(figsize=(10, 6))
top_artistas_chile.sort_values().plot(kind="barh")
plt.title("Top 15 artistas o combinaciones con más apariciones en Chile")
plt.xlabel("Cantidad de apariciones en ranking")
plt.ylabel("Artista o combinación")
plt.tight_layout()
plt.show()

# %%
# Cantidad de canciones únicas por artista o combinación en Chile

canciones_por_artista_chile = (
    chile_clean
    .groupby("artists")["name"]
    .nunique()
    .sort_values(ascending=False)
    .head(15)
)

print(canciones_por_artista_chile)
# Out:
# artists
# Bad Bunny                                                22
# Cris Mj                                                  14
# Kidd Voodoo                                              12
# KAROL G                                                   9
# LOS 4F, Young Cister, Kidd Voodoo, DrefQuila, Easykid     7
# Jere Klein                                                6
# Mora                                                      5
# Entremares                                                5
# Kidd Voodoo, Resonancia Etérea                            5
# Los Bunkers                                               4
# Young Cister                                              4
# Maihuen de los Angeles                                    4
# Taylor Swift                                              4
# Anuel AA                                                  4
# Los Vikings 5                                             4
# Name: name, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
canciones_por_artista_chile.sort_values().plot(kind="barh")
plt.title("Top 15 artistas o combinaciones con más canciones únicas en Chile")
plt.xlabel("Cantidad de canciones únicas")
plt.ylabel("Artista o combinación")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
chile_clean["popularity"].plot(kind="hist", bins=20)
plt.title("Distribución de popularidad de canciones en Chile")
plt.xlabel("Popularidad")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cols_corr = [
    "daily_rank", "daily_movement", "weekly_movement", "popularity",
    "danceability", "energy", "loudness", "speechiness",
    "acousticness", "instrumentalness", "liveness",
    "valence", "tempo", "duration_ms"
]

corr = chile_clean[cols_corr].corr()

plt.figure(figsize=(10, 8))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(cols_corr)), cols_corr, rotation=90)
plt.yticks(range(len(cols_corr)), cols_corr)
plt.title("Mapa de calor de correlaciones en el subconjunto de Chile")
plt.tight_layout()
plt.show()

# %%
## Construcción de base agregada por artista

En esta etapa se transforma el dataset desde el nivel original de canción en ranking diario hacia una base agregada por artista. Esta transformación es necesaria porque el objetivo del proyecto no es modelar canciones individuales, sino identificar perfiles de artistas con potencial de convocatoria para eventos musicales en Chile.

Para esta primera versión se trabajará con la columna `artists` tal como aparece en el dataset, por lo que las colaboraciones se mantienen como combinaciones de artistas. En una etapa posterior se podrá definir un criterio más detallado para separar colaboraciones o featuring.
# Out:
#   Cell In[55], line 3
#     En esta etapa se transforma el dataset desde el nivel original de canción en ranking diario hacia una base agregada por artista. Esta transformación es necesaria porque el objetivo del proyecto no es modelar canciones individuales, sino identificar perfiles de artistas con potencial de convocatoria para eventos musicales en Chile.
#        ^
# SyntaxError: invalid syntax

# %%
# Construcción de base agregada por artista para Chile

# Trabajaremos con una copia del subconjunto limpio de Chile
chile_artistas = chile_clean.copy()

# Asegurar que snapshot_date esté en formato fecha
chile_artistas["snapshot_date"] = pd.to_datetime(chile_artistas["snapshot_date"], errors="coerce")

# Crear base agregada por artista o combinación de artistas
base_artistas_chile = (
    chile_artistas
    .groupby("artists")
    .agg(
        apariciones_chile=("name", "count"),
        canciones_unicas_chile=("name", "nunique"),
        mejor_rank_chile=("daily_rank", "min"),
        peor_rank_chile=("daily_rank", "max"),
        rank_promedio_chile=("daily_rank", "mean"),
        popularidad_promedio=("popularity", "mean"),
        movimiento_diario_promedio=("daily_movement", "mean"),
        movimiento_semanal_promedio=("weekly_movement", "mean"),
        primer_dia_ranking=("snapshot_date", "min"),
        ultimo_dia_ranking=("snapshot_date", "max"),
        permanencia_dias=("snapshot_date", "nunique")
    )
    .reset_index()
)

# Como en Spotify un ranking menor es mejor, se crea una variable invertida:
# si un artista llegó al puesto 1, obtiene mayor puntaje que uno que llegó al puesto 50.
base_artistas_chile["puntaje_posicion_chile"] = 51 - base_artistas_chile["mejor_rank_chile"]

# Ordenar por mayor cantidad de apariciones en Chile
base_artistas_chile = base_artistas_chile.sort_values(
    by="apariciones_chile",
    ascending=False
)

print("Tamaño de la base agregada por artista:", base_artistas_chile.shape)

base_artistas_chile.head(10)
# Out:
# Tamaño de la base agregada por artista: (408, 13)
#                              artists  apariciones_chile  \
# 61                           Cris Mj               1808
# 22                         Bad Bunny               1233
# 180                          KAROL G               1071
# 95                   Feid, ATL Jacob                489
# 367         Tiago PZK, Ke Personajes                399
# 100          FloyyMenor, Lewis Somes                394
# 98               FloyyMenor, Cris Mj                392
# 190            Katteyes, Kidd Voodoo                370
# 256  Lucky Brown, Mateo on the Beatz                357
# 183              KAROL G, Peso Pluma                354
#
#      canciones_unicas_chile  mejor_rank_chile  peor_rank_chile  \
# 61                       14                 1               50
# 22                       22                 1               50
# 180                       9                 1               50
# 95                        1                 3               50
# 367                       1                 5               49
# 100                       4                 2               50
# 98                        2                 1               48
# 190                       2                 1               50
# 256                       2                 1               50
# 183                       1                 2               49
#
#      rank_promedio_chile  popularidad_promedio  movimiento_diario_promedio  \
# 61             20.824115             75.497235                    0.440819
# 22             18.789943             90.673966                    0.356042
# 180            30.783380             88.270775                    0.267040
# 95             19.498978             90.411043                    0.537832
# 367            19.546366             79.511278                    0.508772
# 100            22.695431             74.682741                    0.631980
# 98             17.867347             83.471939                    0.882653
# 190            20.000000             73.821622                    0.416216
# 256            19.529412             68.938375                    1.025210
# 183            26.855932             89.644068                    0.248588
#
#      movimiento_semanal_promedio primer_dia_ranking ultimo_dia_ranking  \
# 61                      1.278761         2023-10-18         2025-06-11
# 22                      2.223033         2023-10-18         2025-06-11
# 180                     0.948646         2023-10-18         2025-06-11
# 95                      0.985685         2023-12-10         2025-05-11
# 367                     1.674185         2024-02-20         2025-05-22
# 100                     3.383249         2024-05-19         2025-05-05
# 98                      2.645408         2024-02-04         2025-04-21
# 190                     1.400000         2023-10-18         2025-05-08
# 256                     4.005602         2024-07-27         2025-06-11
# 183                     0.531073         2023-10-18         2024-10-24
#
#      permanencia_dias  puntaje_posicion_chile
# 61                549                      50
# 22                227                      50
# 180               573                      50
# 95                489                      48
# 367               399                      46
# 100               274                      49
# 98                392                      50
# 190               335                      50
# 256               299                      50
# 183               354                      49

# %%
## Selección y escalamiento de variables para modelamiento

Luego de construir la base agregada por artista, se seleccionaron variables numéricas relacionadas con presencia, permanencia, posición, popularidad, movimiento y diversidad de repertorio. Estas variables serán utilizadas como entrada para PCA y K-Means.

Antes del modelamiento, las variables se escalan mediante `StandardScaler`, ya que presentan rangos distintos. Este paso evita que variables con valores más grandes, como la cantidad de apariciones en ranking, dominen el cálculo de distancias utilizado por K-Means.
# Out:
#   Cell In[58], line 3
#     Luego de construir la base agregada por artista, se seleccionaron variables numéricas relacionadas con presencia, permanencia, posición, popularidad, movimiento y diversidad de repertorio. Estas variables serán utilizadas como entrada para PCA y K-Means.
#           ^
# SyntaxError: invalid syntax

# %%
# Selección de variables para PCA y K-Means

from sklearn.preprocessing import StandardScaler

variables_modelo = [
    "apariciones_chile",
    "canciones_unicas_chile",
    "rank_promedio_chile",
    "popularidad_promedio",
    "movimiento_diario_promedio",
    "movimiento_semanal_promedio",
    "permanencia_dias",
    "puntaje_posicion_chile"
]

# Crear base solo con artistas y variables seleccionadas
base_modelo_artistas = base_artistas_chile[["artists"] + variables_modelo].copy()

# Revisar valores nulos en las variables seleccionadas
print("Valores nulos por variable:")
print(base_modelo_artistas[variables_modelo].isna().sum())

# En caso de existir valores nulos, se reemplazan por la mediana de cada variable
base_modelo_artistas[variables_modelo] = base_modelo_artistas[variables_modelo].fillna(
    base_modelo_artistas[variables_modelo].median()
)

# Escalamiento de variables numéricas
scaler = StandardScaler()
X_scaled = scaler.fit_transform(base_modelo_artistas[variables_modelo])

print("Tamaño de la matriz escalada:", X_scaled.shape)

base_modelo_artistas.head(10)
# Out:
# Valores nulos por variable:
# apariciones_chile              0
# canciones_unicas_chile         0
# rank_promedio_chile            0
# popularidad_promedio           0
# movimiento_diario_promedio     0
# movimiento_semanal_promedio    0
# permanencia_dias               0
# puntaje_posicion_chile         0
# dtype: int64
# Tamaño de la matriz escalada: (408, 8)
#                              artists  apariciones_chile  \
# 61                           Cris Mj               1808
# 22                         Bad Bunny               1233
# 180                          KAROL G               1071
# 95                   Feid, ATL Jacob                489
# 367         Tiago PZK, Ke Personajes                399
# 100          FloyyMenor, Lewis Somes                394
# 98               FloyyMenor, Cris Mj                392
# 190            Katteyes, Kidd Voodoo                370
# 256  Lucky Brown, Mateo on the Beatz                357
# 183              KAROL G, Peso Pluma                354
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 61                       14            20.824115             75.497235
# 22                       22            18.789943             90.673966
# 180                       9            30.783380             88.270775
# 95                        1            19.498978             90.411043
# 367                       1            19.546366             79.511278
# 100                       4            22.695431             74.682741
# 98                        2            17.867347             83.471939
# 190                       2            20.000000             73.821622
# 256                       2            19.529412             68.938375
# 183                       1            26.855932             89.644068
#
#      movimiento_diario_promedio  movimiento_semanal_promedio  \
# 61                     0.440819                     1.278761
# 22                     0.356042                     2.223033
# 180                    0.267040                     0.948646
# 95                     0.537832                     0.985685
# 367                    0.508772                     1.674185
# 100                    0.631980                     3.383249
# 98                     0.882653                     2.645408
# 190                    0.416216                     1.400000
# 256                    1.025210                     4.005602
# 183                    0.248588                     0.531073
#
#      permanencia_dias  puntaje_posicion_chile
# 61                549                      50
# 22                227                      50
# 180               573                      50
# 95                489                      48
# 367               399                      46
# 100               274                      49
# 98                392                      50
# 190               335                      50
# 256               299                      50
# 183               354                      49

# %%
## Aplicación inicial de PCA

En esta etapa se aplica Análisis de Componentes Principales (PCA) sobre la matriz escalada de variables por artista. El objetivo es reducir la dimensionalidad de los datos y observar cuánta varianza explica cada componente principal.

Este paso permite preparar los datos para técnicas de agrupamiento como K-Means y facilita la visualización de perfiles de artistas en menos dimensiones.

# %%
# Aplicación inicial de PCA

from sklearn.decomposition import PCA
import pandas as pd
import matplotlib.pyplot as plt

# Aplicar PCA sobre la matriz escalada
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Calcular varianza explicada por componente
varianza_explicada = pca.explained_variance_ratio_
varianza_acumulada = varianza_explicada.cumsum()

# Crear tabla resumen
tabla_pca = pd.DataFrame({
    "Componente": [f"PC{i+1}" for i in range(len(varianza_explicada))],
    "Varianza explicada": varianza_explicada,
    "Varianza acumulada": varianza_acumulada
})

print(tabla_pca)

# Gráfico de varianza acumulada
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(varianza_acumulada) + 1), varianza_acumulada, marker="o")
plt.title("Varianza acumulada explicada por PCA")
plt.xlabel("Número de componentes principales")
plt.ylabel("Varianza acumulada")
plt.xticks(range(1, len(varianza_acumulada) + 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#   Componente  Varianza explicada  Varianza acumulada
# 0        PC1            0.390381            0.390381
# 1        PC2            0.281431            0.671812
# 2        PC3            0.153817            0.825629
# 3        PC4            0.084469            0.910098
# 4        PC5            0.054705            0.964803
# 5        PC6            0.017690            0.982493
# 6        PC7            0.011162            0.993655
# 7        PC8            0.006345            1.000000

# %%
## Selección de componentes principales para K-Means

A partir del análisis de varianza acumulada, se seleccionan cuatro componentes principales, ya que explican aproximadamente el 91% de la variabilidad total de las variables originales. Estos componentes serán utilizados como entrada para el agrupamiento mediante K-Means.

# %%
# Crear matriz PCA final con 4 componentes principales

pca_final = PCA(n_components=4)
X_pca_4 = pca_final.fit_transform(X_scaled)

# Crear DataFrame con los componentes principales
pca_artistas = pd.DataFrame(
    X_pca_4,
    columns=["PC1", "PC2", "PC3", "PC4"]
)

# Agregar nombre de artista o combinación
pca_artistas["artists"] = base_modelo_artistas["artists"].values

print("Tamaño de la matriz PCA final:", X_pca_4.shape)
print("Varianza acumulada con 4 componentes:", pca_final.explained_variance_ratio_.sum())

pca_artistas.head(10)
# Out:
# Tamaño de la matriz PCA final: (408, 4)
# Varianza acumulada con 4 componentes: 0.9100978447252814
#          PC1       PC2        PC3       PC4                          artists
# 0  12.009546 -1.191874   9.322570  0.683637                          Cris Mj
# 1   9.875921 -0.058030  10.795404  4.254531                        Bad Bunny
# 2   8.634403 -1.397865   5.181078  0.265234                          KAROL G
# 3   5.139290 -0.784922  -0.151998 -1.291530                  Feid, ATL Jacob
# 4   4.123638 -0.539199  -0.172980 -1.339984         Tiago PZK, Ke Personajes
# 5   3.818543 -0.171467   1.202263 -0.348296          FloyyMenor, Lewis Somes
# 6   4.431587 -0.278818   0.065834 -0.984844              FloyyMenor, Cris Mj
# 7   3.871630 -0.338033   0.202164 -1.131168            Katteyes, Kidd Voodoo
# 8   3.532270 -0.007689   0.274489 -1.141829  Lucky Brown, Mateo on the Beatz
# 9   3.713270 -0.818911  -0.395161 -0.734676              KAROL G, Peso Pluma

# %% [markdown]
# ## Evaluación preliminar del número de clusters
#
# Una vez reducida la dimensionalidad mediante PCA, se evalúa el número de clusters para K-Means. Para esto se prueban distintos valores de `k` y se comparan métricas internas de clustering: Silhouette Score, Davies-Bouldin Index y Calinski-Harabasz Index.
#
# Estas métricas permiten analizar si los grupos formados son compactos y están bien separados. Sin embargo, la elección final del número de clusters también debe considerar la interpretación de los perfiles de artistas y la coherencia con el objetivo del proyecto.

# %%
# Evaluación de número de clusters para K-Means

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import pandas as pd
import matplotlib.pyplot as plt

resultados_kmeans = []

# Probar distintos valores de k
for k in range(2, 9):
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )
    
    labels = kmeans.fit_predict(X_pca_4)
    
    silhouette = silhouette_score(X_pca_4, labels)
    davies_bouldin = davies_bouldin_score(X_pca_4, labels)
    calinski_harabasz = calinski_harabasz_score(X_pca_4, labels)
    
    resultados_kmeans.append({
        "k": k,
        "Silhouette Score": silhouette,
        "Davies-Bouldin Index": davies_bouldin,
        "Calinski-Harabasz Index": calinski_harabasz
    })

tabla_kmeans = pd.DataFrame(resultados_kmeans)

tabla_kmeans
# Out:
#    k  Silhouette Score  Davies-Bouldin Index  Calinski-Harabasz Index
# 0  2          0.319080              1.248525               150.599154
# 1  3          0.392540              0.916904               194.997761
# 2  4          0.407501              0.748952               250.269018
# 3  5          0.399601              0.727413               257.533141
# 4  6          0.351161              0.836720               257.147838
# 5  7          0.351824              0.885175               253.202720
# 6  8          0.305743              0.945594               247.794033

# %%
# Gráfico de Silhouette Score

plt.figure(figsize=(8, 5))
plt.plot(tabla_kmeans["k"], tabla_kmeans["Silhouette Score"], marker="o")
plt.title("Silhouette Score según número de clusters")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Silhouette Score")
plt.xticks(tabla_kmeans["k"])
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Gráfico de Davies-Bouldin Index

plt.figure(figsize=(8, 5))
plt.plot(tabla_kmeans["k"], tabla_kmeans["Davies-Bouldin Index"], marker="o")
plt.title("Davies-Bouldin Index según número de clusters")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Davies-Bouldin Index")
plt.xticks(tabla_kmeans["k"])
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Aplicación inicial de K-Means con cuatro clusters
#
# A partir de la evaluación preliminar de métricas internas, se selecciona inicialmente `k = 4` para aplicar K-Means. Esta elección se basa principalmente en el Silhouette Score, que alcanza su valor más alto con cuatro clusters, y en la necesidad de obtener una primera segmentación interpretable de artistas.
#
# El resultado permitirá asignar cada artista o combinación de artistas a un perfil preliminar según su comportamiento en rankings de Spotify Chile.

# %%
# Aplicación final de K-Means con k = 4

k_optimo = 4

kmeans_final = KMeans(
    n_clusters=k_optimo,
    random_state=42,
    n_init=10
)

# Asignar cluster a cada artista
clusters = kmeans_final.fit_predict(X_pca_4)

# Agregar cluster a las bases de trabajo
base_modelo_artistas["cluster"] = clusters
pca_artistas["cluster"] = clusters

# Ver cantidad de artistas por cluster
conteo_clusters = base_modelo_artistas["cluster"].value_counts().sort_index()

print("Cantidad de artistas por cluster:")
print(conteo_clusters)

base_modelo_artistas.head(10)
# Out:
# Cantidad de artistas por cluster:
# cluster
# 0    165
# 1     53
# 2      3
# 3    187
# Name: count, dtype: int64
#                              artists  apariciones_chile  \
# 61                           Cris Mj               1808
# 22                         Bad Bunny               1233
# 180                          KAROL G               1071
# 95                   Feid, ATL Jacob                489
# 367         Tiago PZK, Ke Personajes                399
# 100          FloyyMenor, Lewis Somes                394
# 98               FloyyMenor, Cris Mj                392
# 190            Katteyes, Kidd Voodoo                370
# 256  Lucky Brown, Mateo on the Beatz                357
# 183              KAROL G, Peso Pluma                354
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 61                       14            20.824115             75.497235
# 22                       22            18.789943             90.673966
# 180                       9            30.783380             88.270775
# 95                        1            19.498978             90.411043
# 367                       1            19.546366             79.511278
# 100                       4            22.695431             74.682741
# 98                        2            17.867347             83.471939
# 190                       2            20.000000             73.821622
# 256                       2            19.529412             68.938375
# 183                       1            26.855932             89.644068
#
#      movimiento_diario_promedio  movimiento_semanal_promedio  \
# 61                     0.440819                     1.278761
# 22                     0.356042                     2.223033
# 180                    0.267040                     0.948646
# 95                     0.537832                     0.985685
# 367                    0.508772                     1.674185
# 100                    0.631980                     3.383249
# 98                     0.882653                     2.645408
# 190                    0.416216                     1.400000
# 256                    1.025210                     4.005602
# 183                    0.248588                     0.531073
#
#      permanencia_dias  puntaje_posicion_chile  cluster
# 61                549                      50        2
# 22                227                      50        2
# 180               573                      50        2
# 95                489                      48        0
# 367               399                      46        0
# 100               274                      49        0
# 98                392                      50        0
# 190               335                      50        0
# 256               299                      50        0
# 183               354                      49        0

# %% [markdown]
# ## Caracterización inicial de los clusters
#
# Luego de aplicar K-Means con cuatro clusters, se analizan las variables promedio de cada grupo. Este paso permite interpretar qué tipo de artistas reúne cada cluster, considerando métricas como apariciones en rankings de Chile, canciones únicas, posición promedio, popularidad, movimiento y permanencia.
#
# La interpretación de clusters es necesaria porque K-Means solo asigna números de grupo, pero no entrega automáticamente un significado para cada perfil.

# %%
# Caracterización de clusters mediante promedios de variables

# Calcular promedios por cluster
resumen_clusters = (
    base_modelo_artistas
    .groupby("cluster")[variables_modelo]
    .mean()
    .round(2)
)

# Agregar cantidad de artistas por cluster
conteo_clusters = base_modelo_artistas["cluster"].value_counts().sort_index()
resumen_clusters.insert(0, "cantidad_artistas", conteo_clusters)

resumen_clusters
# Out:
#          cantidad_artistas  apariciones_chile  canciones_unicas_chile  \
# cluster
# 0                      165             132.72                    1.41
# 1                       53               4.43                    1.60
# 2                        3            1370.67                   15.00
# 3                      187              15.28                    1.16
#
#          rank_promedio_chile  popularidad_promedio  \
# cluster
# 0                      24.63                 76.62
# 1                      23.27                 55.37
# 2                      23.47                 84.81
# 3                      42.56                 60.67
#
#          movimiento_diario_promedio  movimiento_semanal_promedio  \
# cluster
# 0                              0.59                         2.68
# 1                             17.39                        26.47
# 2                              0.35                         1.48
# 3                              2.04                         4.27
#
#          permanencia_dias  puntaje_posicion_chile
# cluster
# 0                  127.78                   42.51
# 1                    3.30                   35.55
# 2                  449.67                   50.00
# 3                   14.82                   15.75

# %%
# Ver principales artistas de cada cluster según apariciones en Chile

from IPython.display import display

columnas_revision = [
    "artists",
    "cluster",
    "apariciones_chile",
    "canciones_unicas_chile",
    "rank_promedio_chile",
    "popularidad_promedio",
    "permanencia_dias",
    "puntaje_posicion_chile"
]

for cluster_id in sorted(base_modelo_artistas["cluster"].unique()):
    print(f"\nCluster {cluster_id}")
    
    muestra_cluster = (
        base_modelo_artistas[base_modelo_artistas["cluster"] == cluster_id]
        .sort_values(by="apariciones_chile", ascending=False)
        [columnas_revision]
        .head(10)
    )
    
    display(muestra_cluster)
# Out:
# Cluster 0
#                              artists  cluster  apariciones_chile  \
# 95                   Feid, ATL Jacob        0                489
# 367         Tiago PZK, Ke Personajes        0                399
# 100          FloyyMenor, Lewis Somes        0                394
# 98               FloyyMenor, Cris Mj        0                392
# 190            Katteyes, Kidd Voodoo        0                370
# 256  Lucky Brown, Mateo on the Beatz        0                357
# 183              KAROL G, Peso Pluma        0                354
# 287                      Myke Towers        0                340
# 163                            Jimin        0                321
# 331                           Plan B        0                318
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 95                        1            19.498978             90.411043
# 367                       1            19.546366             79.511278
# 100                       4            22.695431             74.682741
# 98                        2            17.867347             83.471939
# 190                       2            20.000000             73.821622
# 256                       2            19.529412             68.938375
# 183                       1            26.855932             89.644068
# 287                       2            25.297059             91.623529
# 163                       2            11.862928             89.971963
# 331                       1            37.286164             78.000000
#
#      permanencia_dias  puntaje_posicion_chile
# 95                489                      48
# 367               399                      46
# 100               274                      49
# 98                392                      50
# 190               335                      50
# 256               299                      50
# 183               354                      49
# 287               272                      46
# 163               309                      50
# 331               318                      31
# Cluster 1
#                                                artists  cluster  \
# 224  LOS 4F, Young Cister, Kidd Voodoo, DrefQuila, ...        1
# 346                                         Santaferia        1
# 402                                     benjitalkapone        1
# 242                                Los Hermanos Campos        1
# 260                                        Luis Miguel        1
# 351             Sevdaliza, Villano Antillano, Tokischa        1
# 233                             La Sonora De Tommy Rey        1
# 228  LOS 4F, Young Cister, Kidd Voodoo, Easykid, Dr...        1
# 44                                    Blessd, Anuel AA        1
# 359                                    Sonora Palacios        1
#
#      apariciones_chile  canciones_unicas_chile  rank_promedio_chile  \
# 224                 19                       7            26.578947
# 346                 15                       3            31.466667
# 402                 14                       1            13.000000
# 242                 10                       3            22.600000
# 260                  9                       4            30.111111
# 351                  9                       1            32.000000
# 233                  8                       4            12.000000
# 228                  7                       1            16.857143
# 44                   6                       1            20.500000
# 359                  6                       3             9.500000
#
#      popularidad_promedio  permanencia_dias  puntaje_posicion_chile
# 224             33.315789                 4                      42
# 346             63.266667                 8                      33
# 402             63.214286                14                      50
# 242             59.300000                 4                      46
# 260             71.888889                 4                      42
# 351             84.111111                 9                      32
# 233             40.875000                 2                      46
# 228             48.428571                 7                      44
# 44              72.333333                 6                      40
# 359             49.500000                 2                      48
# Cluster 2
#        artists  cluster  apariciones_chile  canciones_unicas_chile  \
# 61     Cris Mj        2               1808                      14
# 22   Bad Bunny        2               1233                      22
# 180    KAROL G        2               1071                       9
#
#      rank_promedio_chile  popularidad_promedio  permanencia_dias  \
# 61             20.824115             75.497235               549
# 22             18.789943             90.673966               227
# 180            30.783380             88.270775               573
#
#      puntaje_posicion_chile
# 61                       50
# 22                       50
# 180                      50
# Cluster 3
#                                   artists  cluster  apariciones_chile  \
# 321                       Pailita, Fran C        3                101
# 297               Nickoog Clk, Gittobeatz        3                 97
# 2                      Ak4:20, Gino Mella        3                 90
# 345                     Sabrina Carpenter        3                 89
# 185                      KAROL G, Shakira        3                 82
# 368           Tobal Mj, Cris Mj, Kail BRL        3                 82
# 41                          Billie Eilish        3                 74
# 104  Fran C, Kevin Martes 13, Galee Galee        3                 70
# 400                      Young Miko, Feid        3                 70
# 33         Bad Gyal, Tokischa, Young Miko        3                 67
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 321                       1            41.950495             74.207921
# 297                       1            40.896907             70.886598
# 2                         2            38.233333             70.355556
# 345                       3            40.764045             95.528090
# 185                       1            43.402439             88.682927
# 368                       1            43.000000             66.195122
# 41                        3            45.648649             97.459459
# 104                       1            37.685714             63.314286
# 400                       1            38.314286             85.571429
# 33                        1            40.149254             89.253731
#
#      permanencia_dias  puntaje_posicion_chile
# 321               101                      18
# 297                97                      16
# 2                  90                      29
# 345                50                      28
# 185                82                      27
# 368                82                      17
# 41                 72                      14
# 104                70                      27
# 400                70                      29
# 33                 67                      21

# %%
# Mostrar resumen de clusters en formato más fácil de leer

pd.set_option("display.max_columns", None)

resumen_clusters.T
# Out:
# cluster                           0      1        2       3
# cantidad_artistas            165.00  53.00     3.00  187.00
# apariciones_chile            132.72   4.43  1370.67   15.28
# canciones_unicas_chile         1.41   1.60    15.00    1.16
# rank_promedio_chile           24.63  23.27    23.47   42.56
# popularidad_promedio          76.62  55.37    84.81   60.67
# movimiento_diario_promedio     0.59  17.39     0.35    2.04
# movimiento_semanal_promedio    2.68  26.47     1.48    4.27
# permanencia_dias             127.78   3.30   449.67   14.82
# puntaje_posicion_chile        42.51  35.55    50.00   15.75

# %%
# Revisar todos los artistas del cluster 2

base_modelo_artistas[
    base_modelo_artistas["cluster"] == 2
][[
    "artists",
    "cluster",
    "apariciones_chile",
    "canciones_unicas_chile",
    "rank_promedio_chile",
    "popularidad_promedio",
    "permanencia_dias",
    "puntaje_posicion_chile"
]].sort_values(by="apariciones_chile", ascending=False)
# Out:
#        artists  cluster  apariciones_chile  canciones_unicas_chile  \
# 61     Cris Mj        2               1808                      14
# 22   Bad Bunny        2               1233                      22
# 180    KAROL G        2               1071                       9
#
#      rank_promedio_chile  popularidad_promedio  permanencia_dias  \
# 61             20.824115             75.497235               549
# 22             18.789943             90.673966               227
# 180            30.783380             88.270775               573
#
#      puntaje_posicion_chile
# 61                       50
# 22                       50
# 180                      50

# %%
# Principales artistas por cluster según apariciones en Chile

columnas_revision = [
    "artists",
    "cluster",
    "apariciones_chile",
    "canciones_unicas_chile",
    "rank_promedio_chile",
    "popularidad_promedio",
    "permanencia_dias",
    "puntaje_posicion_chile"
]

for cluster_id in sorted(base_modelo_artistas["cluster"].unique()):
    print(f"\n===== Cluster {cluster_id} =====")
    
    muestra_cluster = (
        base_modelo_artistas[base_modelo_artistas["cluster"] == cluster_id]
        .sort_values(by="apariciones_chile", ascending=False)
        [columnas_revision]
        .head(10)
    )
    
    display(muestra_cluster)
# Out:
# ===== Cluster 0 =====
#                              artists  cluster  apariciones_chile  \
# 95                   Feid, ATL Jacob        0                489
# 367         Tiago PZK, Ke Personajes        0                399
# 100          FloyyMenor, Lewis Somes        0                394
# 98               FloyyMenor, Cris Mj        0                392
# 190            Katteyes, Kidd Voodoo        0                370
# 256  Lucky Brown, Mateo on the Beatz        0                357
# 183              KAROL G, Peso Pluma        0                354
# 287                      Myke Towers        0                340
# 163                            Jimin        0                321
# 331                           Plan B        0                318
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 95                        1            19.498978             90.411043
# 367                       1            19.546366             79.511278
# 100                       4            22.695431             74.682741
# 98                        2            17.867347             83.471939
# 190                       2            20.000000             73.821622
# 256                       2            19.529412             68.938375
# 183                       1            26.855932             89.644068
# 287                       2            25.297059             91.623529
# 163                       2            11.862928             89.971963
# 331                       1            37.286164             78.000000
#
#      permanencia_dias  puntaje_posicion_chile
# 95                489                      48
# 367               399                      46
# 100               274                      49
# 98                392                      50
# 190               335                      50
# 256               299                      50
# 183               354                      49
# 287               272                      46
# 163               309                      50
# 331               318                      31
# ===== Cluster 1 =====
#                                                artists  cluster  \
# 224  LOS 4F, Young Cister, Kidd Voodoo, DrefQuila, ...        1
# 346                                         Santaferia        1
# 402                                     benjitalkapone        1
# 242                                Los Hermanos Campos        1
# 260                                        Luis Miguel        1
# 351             Sevdaliza, Villano Antillano, Tokischa        1
# 233                             La Sonora De Tommy Rey        1
# 228  LOS 4F, Young Cister, Kidd Voodoo, Easykid, Dr...        1
# 44                                    Blessd, Anuel AA        1
# 359                                    Sonora Palacios        1
#
#      apariciones_chile  canciones_unicas_chile  rank_promedio_chile  \
# 224                 19                       7            26.578947
# 346                 15                       3            31.466667
# 402                 14                       1            13.000000
# 242                 10                       3            22.600000
# 260                  9                       4            30.111111
# 351                  9                       1            32.000000
# 233                  8                       4            12.000000
# 228                  7                       1            16.857143
# 44                   6                       1            20.500000
# 359                  6                       3             9.500000
#
#      popularidad_promedio  permanencia_dias  puntaje_posicion_chile
# 224             33.315789                 4                      42
# 346             63.266667                 8                      33
# 402             63.214286                14                      50
# 242             59.300000                 4                      46
# 260             71.888889                 4                      42
# 351             84.111111                 9                      32
# 233             40.875000                 2                      46
# 228             48.428571                 7                      44
# 44              72.333333                 6                      40
# 359             49.500000                 2                      48
# ===== Cluster 2 =====
#        artists  cluster  apariciones_chile  canciones_unicas_chile  \
# 61     Cris Mj        2               1808                      14
# 22   Bad Bunny        2               1233                      22
# 180    KAROL G        2               1071                       9
#
#      rank_promedio_chile  popularidad_promedio  permanencia_dias  \
# 61             20.824115             75.497235               549
# 22             18.789943             90.673966               227
# 180            30.783380             88.270775               573
#
#      puntaje_posicion_chile
# 61                       50
# 22                       50
# 180                      50
# ===== Cluster 3 =====
#                                   artists  cluster  apariciones_chile  \
# 321                       Pailita, Fran C        3                101
# 297               Nickoog Clk, Gittobeatz        3                 97
# 2                      Ak4:20, Gino Mella        3                 90
# 345                     Sabrina Carpenter        3                 89
# 185                      KAROL G, Shakira        3                 82
# 368           Tobal Mj, Cris Mj, Kail BRL        3                 82
# 41                          Billie Eilish        3                 74
# 104  Fran C, Kevin Martes 13, Galee Galee        3                 70
# 400                      Young Miko, Feid        3                 70
# 33         Bad Gyal, Tokischa, Young Miko        3                 67
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 321                       1            41.950495             74.207921
# 297                       1            40.896907             70.886598
# 2                         2            38.233333             70.355556
# 345                       3            40.764045             95.528090
# 185                       1            43.402439             88.682927
# 368                       1            43.000000             66.195122
# 41                        3            45.648649             97.459459
# 104                       1            37.685714             63.314286
# 400                       1            38.314286             85.571429
# 33                        1            40.149254             89.253731
#
#      permanencia_dias  puntaje_posicion_chile
# 321               101                      18
# 297                97                      16
# 2                  90                      29
# 345                50                      28
# 185                82                      27
# 368                82                      17
# 41                 72                      14
# 104                70                      27
# 400                70                      29
# 33                 67                      21

# %% [markdown]
# ## Asignación preliminar de nombres a los perfiles
#
# A partir del resumen estadístico de cada cluster, se asignan nombres interpretativos preliminares a los perfiles de artistas. Estos nombres no son generados automáticamente por K-Means, sino que se definen a partir de las características promedio de cada grupo, como apariciones en ranking, canciones únicas, popularidad, permanencia y posición promedio.

# %%
# Asignar nombres interpretativos a los clusters

nombres_clusters = {
    0: "Presencia sostenida en rankings chilenos",
    1: "Aparición puntual o comportamiento emergente",
    2: "Artistas consolidados de alto desempeño local",
    3: "Baja presencia o menor posicionamiento local"
}

base_modelo_artistas["perfil_cluster"] = base_modelo_artistas["cluster"].map(nombres_clusters)
pca_artistas["perfil_cluster"] = pca_artistas["cluster"].map(nombres_clusters)

# Revisar resultado
base_modelo_artistas[[
    "artists",
    "cluster",
    "perfil_cluster",
    "apariciones_chile",
    "canciones_unicas_chile",
    "rank_promedio_chile",
    "popularidad_promedio",
    "permanencia_dias"
]].head(15)
# Out:
#                                           artists  cluster  \
# 61                                        Cris Mj        2
# 22                                      Bad Bunny        2
# 180                                       KAROL G        2
# 95                                Feid, ATL Jacob        0
# 367                      Tiago PZK, Ke Personajes        0
# 100                       FloyyMenor, Lewis Somes        0
# 98                            FloyyMenor, Cris Mj        0
# 190                         Katteyes, Kidd Voodoo        0
# 256               Lucky Brown, Mateo on the Beatz        0
# 183                           KAROL G, Peso Pluma        0
# 287                                   Myke Towers        0
# 163                                         Jimin        0
# 331                                        Plan B        0
# 249                         Lucky Brown, Big Cvyu        0
# 159  Jere Klein, Nickoog Clk, Lucky Brown, El BAI        0
#
#                                     perfil_cluster  apariciones_chile  \
# 61   Artistas consolidados de alto desempeño local               1808
# 22   Artistas consolidados de alto desempeño local               1233
# 180  Artistas consolidados de alto desempeño local               1071
# 95        Presencia sostenida en rankings chilenos                489
# 367       Presencia sostenida en rankings chilenos                399
# 100       Presencia sostenida en rankings chilenos                394
# 98        Presencia sostenida en rankings chilenos                392
# 190       Presencia sostenida en rankings chilenos                370
# 256       Presencia sostenida en rankings chilenos                357
# 183       Presencia sostenida en rankings chilenos                354
# 287       Presencia sostenida en rankings chilenos                340
# 163       Presencia sostenida en rankings chilenos                321
# 331       Presencia sostenida en rankings chilenos                318
# 249       Presencia sostenida en rankings chilenos                311
# 159       Presencia sostenida en rankings chilenos                308
#
#      canciones_unicas_chile  rank_promedio_chile  popularidad_promedio  \
# 61                       14            20.824115             75.497235
# 22                       22            18.789943             90.673966
# 180                       9            30.783380             88.270775
# 95                        1            19.498978             90.411043
# 367                       1            19.546366             79.511278
# 100                       4            22.695431             74.682741
# 98                        2            17.867347             83.471939
# 190                       2            20.000000             73.821622
# 256                       2            19.529412             68.938375
# 183                       1            26.855932             89.644068
# 287                       2            25.297059             91.623529
# 163                       2            11.862928             89.971963
# 331                       1            37.286164             78.000000
# 249                       2            20.636656             70.257235
# 159                       1            20.340909             76.561688
#
#      permanencia_dias
# 61                549
# 22                227
# 180               573
# 95                489
# 367               399
# 100               274
# 98                392
# 190               335
# 256               299
# 183               354
# 287               272
# 163               309
# 331               318
# 249               311
# 159               308

# %% [markdown]
# ## Visualización de clusters en el plano PCA
#
# Para visualizar la segmentación obtenida mediante K-Means, se construye un gráfico de dispersión utilizando los dos primeros componentes principales de PCA. Cada punto representa un artista o combinación de artistas, y el color indica el cluster asignado por el modelo.
#
# Esta visualización permite observar de forma general la separación entre perfiles de artistas.

# %%
# Visualización de clusters usando los dos primeros componentes principales

import matplotlib.pyplot as plt

plt.figure(figsize=(9, 6))

scatter = plt.scatter(
    pca_artistas["PC1"],
    pca_artistas["PC2"],
    c=pca_artistas["cluster"],
    alpha=0.8
)

plt.title("Clusters de artistas según PCA y K-Means")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.colorbar(scatter, label="Cluster")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Visualización de clusters destacando los artistas del cluster 2

plt.figure(figsize=(9, 6))

scatter = plt.scatter(
    pca_artistas["PC1"],
    pca_artistas["PC2"],
    c=pca_artistas["cluster"],
    alpha=0.8
)

# Agregar etiquetas solo a los artistas del cluster 2
cluster_2 = pca_artistas[pca_artistas["cluster"] == 2]

for _, row in cluster_2.iterrows():
    plt.text(
        row["PC1"],
        row["PC2"],
        row["artists"],
        fontsize=9
    )

plt.title("Clusters de artistas con identificación del cluster de alto desempeño")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.colorbar(scatter, label="Cluster")
plt.grid(True)
plt.tight_layout()
plt.show()
