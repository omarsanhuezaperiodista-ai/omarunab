# %%
git status
# Out:
#   Cell In[1], line 1
#     git status
#         ^
# SyntaxError: invalid syntax

# %%
git Status
# Out:
#   Cell In[2], line 1
#     git Status
#         ^
# SyntaxError: invalid syntax

# %%
git status
# Out:
#   Cell In[3], line 1
#     git status
#         ^
# SyntaxError: invalid syntax

# %%
git commit -m "Crea estructura inicial del proyecto"
# Out:
#   Cell In[4], line 1
#     git commit -m "Crea estructura inicial del proyecto"
#         ^
# SyntaxError: invalid syntax

# %%
touch README.md
# Out:
#   Cell In[5], line 1
#     touch README.md
#           ^
# SyntaxError: invalid syntax
